table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# see data types
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- UDI: integer (nullable = true)
# -- Product ID: string (nullable = true)
# -- Type: string (nullable = true)
# -- Air temperature [K]: double (nullable = true)
# -- Process temperature [K]: double (nullable = true)
# -- Rotational speed [rpm]: integer (nullable = true)
# -- Torque [Nm]: double (nullable = true)
# -- Tool wear [min]: integer (nullable = true)
# -- Machine failure: integer (nullable = true)
# -- TWF: integer (nullable = true)
# -- HDF: integer (nullable = true)
# -- PWF: integer (nullable = true)
# -- OSF: integer (nullable = true)
# -- RNF: integer (nullable = true)
#
# </div>

# %%
from pyspark.sql.types import StringType
df = df.withColumn("Machine failure",df["Machine failure"].cast(StringType()))
#we can import 'DateType', 'IntegerType', etc. to change data type.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- UDI: integer (nullable = true)
# -- Product ID: string (nullable = true)
# -- Type: string (nullable = true)
# -- Air temperature [K]: double (nullable = true)
# -- Process temperature [K]: double (nullable = true)
# -- Rotational speed [rpm]: integer (nullable = true)
# -- Torque [Nm]: double (nullable = true)
# -- Tool wear [min]: integer (nullable = true)
# -- Machine failure: string (nullable = true)
# -- TWF: integer (nullable = true)
# -- HDF: integer (nullable = true)
# -- PWF: integer (nullable = true)
# -- OSF: integer (nullable = true)
# -- RNF: integer (nullable = true)
#
# </div>

# %%
# check for null values
from pyspark.sql.functions import isnan, when, count, col
df.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for (c) in df.columns]).show()

#spark has lazy execution, need to give some action command to see the result. (like .show() in this case)
# see columns and null values in it.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+----------+----+-------------------+-----------------------+----------------------+-----------+---------------+---------------+---+---+---+---+---+
# UDI|Product ID|Type|Air temperature [K]|Process temperature [K]|Rotational speed [rpm]|Torque [Nm]|Tool wear [min]|Machine failure|TWF|HDF|PWF|OSF|RNF|
# +---+----------+----+-------------------+-----------------------+----------------------+-----------+---------------+---------------+---+---+---+---+---+
#   0|         0| 215|                264|                    287|                  1033|       1154|           1132|              0|  4|  1|  0|  1|  1|
# +---+----------+----+-------------------+-----------------------+----------------------+-----------+---------------+---------------+---+---+---+---+---+
#
# </div>

# %%
#convert spark DataFrame to Pandas DataFRame
pd_df = df.toPandas()
# we can convert spark df to pandas df if the data frame is not huge. As pandas will take all data into single node driver memory. (spark does it on distributed memory).
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import matplotlib.pyplot as plt
plt.clf()
plt.plot(pd_df['Machine failure'], pd_df['Rotational speed [rpm]'], '.')
plt.xlabel('Machine failure')
plt.ylabel('speed [rpm]')
display()

# %%
df.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------------------+----------+----+-------------------+-----------------------+----------------------+-----------------+------------------+-----------------+--------------------+--------------------+-------------------+-------------------+--------------------+
# summary|               UDI|Product ID|Type|Air temperature [K]|Process temperature [K]|Rotational speed [rpm]|      Torque [Nm]|   Tool wear [min]|  Machine failure|                 TWF|                 HDF|                PWF|                OSF|                 RNF|
# +-------+------------------+----------+----+-------------------+-----------------------+----------------------+-----------------+------------------+-----------------+--------------------+--------------------+-------------------+-------------------+--------------------+
#   count|             10000|     10000|9785|               9736|                   9713|                  8967|             8846|              8868|            10000|                9996|                9999|              10000|               9999|                9999|
#    mean|            5000.5|      null|null|  300.0273007395219|      310.0021414598989|    1538.8703022192483|40.01415328962244|107.94440685611187|           0.0339|0.004601840736294518|0.011501150115011502|             0.0095| 0.0097009700970097|0.001900190019001...|
#  stddev|2886.8956799071675|      null|null| 2.0198130946151247|     1.5021838666413492|    179.86912614076903|9.989811814046403| 63.64268274647264|0.180980842650654| 0.06768398698111612| 0.10663025262950723|0.09700871645943422|0.09801949884839203|0.043551911470823705|
#     min|                 1|    H29424|   H|              295.3|                  305.7|                  1168|              3.8|                 0|                0|                   0|                   0|                  0|                  0|                   0|
#     max|             10000|    M24859|   M|              304.5|                  313.8|                  2886|             76.6|               253|                1|                   1|                   1|                  1|                  1|                   1|
# +-------+------------------+----------+----+-------------------+-----------------------+----------------------+-----------------+------------------+-----------------+--------------------+--------------------+-------------------+-------------------+--------------------+
#
# </div>

# %%
df.select("Air temperature [K]", "Process temperature [K]","Rotational speed [rpm]","Torque [Nm]","Tool wear [min]","Machine failure").describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------------------+-----------------------+----------------------+-----------------+------------------+-----------------+
# summary|Air temperature [K]|Process temperature [K]|Rotational speed [rpm]|      Torque [Nm]|   Tool wear [min]|  Machine failure|
# +-------+-------------------+-----------------------+----------------------+-----------------+------------------+-----------------+
#   count|               9736|                   9713|                  8967|             8846|              8868|            10000|
#    mean|  300.0273007395219|      310.0021414598989|    1538.8703022192483|40.01415328962244|107.94440685611187|           0.0339|
#  stddev| 2.0198130946151247|     1.5021838666413492|    179.86912614076903|9.989811814046403| 63.64268274647264|0.180980842650654|
#     min|              295.3|                  305.7|                  1168|              3.8|                 0|                0|
#     max|              304.5|                  313.8|                  2886|             76.6|               253|                1|
# +-------+-------------------+-----------------------+----------------------+-----------------+------------------+-----------------+
#
# </div>

# %%
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[85]: [&#39;UDI&#39;,
#  &#39;Product ID&#39;,
#  &#39;Type&#39;,
#  &#39;Air temperature [K]&#39;,
#  &#39;Process temperature [K]&#39;,
#  &#39;Rotational speed [rpm]&#39;,
#  &#39;Torque [Nm]&#39;,
#  &#39;Tool wear [min]&#39;,
#  &#39;Machine failure&#39;,
#  &#39;TWF&#39;,
#  &#39;HDF&#39;,
#  &#39;PWF&#39;,
#  &#39;OSF&#39;,
#  &#39;RNF&#39;]</div>

# %%
# create frequency table 
df.crosstab('Air temperature [K]', 'Process temperature [K]')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[86]: DataFrame[Air temperature [K]_Process temperature [K]: string, 305.7: bigint, 305.8: bigint, 305.9: bigint, 306.0: bigint, 306.1: bigint, 306.2: bigint, 306.3: bigint, 306.4: bigint, 306.5: bigint, 306.6: bigint, 306.7: bigint, 306.8: bigint, 306.9: bigint, 307.0: bigint, 307.1: bigint, 307.2: bigint, 307.3: bigint, 307.4: bigint, 307.5: bigint, 307.6: bigint, 307.7: bigint, 307.8: bigint, 307.9: bigint, 308.0: bigint, 308.1: bigint, 308.2: bigint, 308.3: bigint, 308.4: bigint, 308.5: bigint, 308.6: bigint, 308.7: bigint, 308.8: bigint, 308.9: bigint, 309.0: bigint, 309.1: bigint, 309.2: bigint, 309.3: bigint, 309.4: bigint, 309.5: bigint, 309.6: bigint, 309.7: bigint, 309.8: bigint, 309.9: bigint, 310.0: bigint, 310.1: bigint, 310.2: bigint, 310.3: bigint, 310.4: bigint, 310.5: bigint, 310.6: bigint, 310.7: bigint, 310.8: bigint, 310.9: bigint, 311.0: bigint, 311.1: bigint, 311.2: bigint, 311.3: bigint, 311.4: bigint, 311.5: bigint, 311.6: bigint, 311.7: bigint, 311.8: bigint, 311.9: bigint, 312.0: bigint, 312.1: bigint, 312.2: bigint, 312.3: bigint, 312.4: bigint, 312.5: bigint, 312.6: bigint, 312.7: bigint, 312.8: bigint, 312.9: bigint, 313.0: bigint, 313.1: bigint, 313.2: bigint, 313.3: bigint, 313.4: bigint, 313.5: bigint, 313.6: bigint, 313.7: bigint, 313.8: bigint, null: bigint]</div>

# %%
# see relation between two columns
df.corr('Air temperature [K]', 'Process temperature [K]')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[87]: -0.019612534319816525</div>

# %%
df.corr('Rotational speed [rpm]', 'Torque [Nm]')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[88]: -0.23780629526895056</div>

# %%
# Some columns have no impact on output of the model, need to be removed.
#cols=['UDI', 'Product ID','TWF', 'HDF', 'PWF', 'OSF','RNF'] columns to be removed.
df.drop('UDI', 'Product ID','TWF', 'HDF', 'PWF', 'OSF','RNF')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[89]: DataFrame[Type: string, Air temperature [K]: double, Process temperature [K]: double, Rotational speed [rpm]: int, Torque [Nm]: double, Tool wear [min]: int, Machine failure: string]</div>

# %%
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[90]: [&#39;UDI&#39;,
#  &#39;Product ID&#39;,
#  &#39;Type&#39;,
#  &#39;Air temperature [K]&#39;,
#  &#39;Process temperature [K]&#39;,
#  &#39;Rotational speed [rpm]&#39;,
#  &#39;Torque [Nm]&#39;,
#  &#39;Tool wear [min]&#39;,
#  &#39;Machine failure&#39;,
#  &#39;TWF&#39;,
#  &#39;HDF&#39;,
#  &#39;PWF&#39;,
#  &#39;OSF&#39;,
#  &#39;RNF&#39;]</div>

# %%
# create new dataframe with same name.
df = df.drop('UDI', 'Product ID','TWF', 'HDF', 'PWF', 'OSF','RNF')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# see if specified columns are removed.
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[92]: [&#39;Type&#39;,
#  &#39;Air temperature [K]&#39;,
#  &#39;Process temperature [K]&#39;,
#  &#39;Rotational speed [rpm]&#39;,
#  &#39;Torque [Nm]&#39;,
#  &#39;Tool wear [min]&#39;,
#  &#39;Machine failure&#39;]</div>

# %%
df.groupBy('Machine failure').count().show()
# 339 times machine is failed
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------------+-----+
# Machine failure|count|
# +---------------+-----+
#               0| 9661|
#               1|  339|
# +---------------+-----+
#
# </div>

# %%
# we have data converted to the pandas since our data set is small we can convert it to pandas.
# i want put some graph usin seaborn library.
import seaborn as sns
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#counting the number of product according to the product quality.
sns.countplot(x='Type',data=pd_df)
pd.crosstab(pd_df['Type'], columns='count')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[95]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>col_0</th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>H</th>
#       <td>985</td>
#     </tr>
#     <tr>
#       <th>L</th>
#       <td>5879</td>
#     </tr>
#     <tr>
#       <th>M</th>
#       <td>2921</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
sns.countplot(x='Type',hue='Machine failure', data=pd_df) # more failure for low quality product.
pd.crosstab(pd_df['Type'], columns=pd_df['Machine failure'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[96]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Machine failure</th>
#       <th>0</th>
#       <th>1</th>
#     </tr>
#     <tr>
#       <th>Type</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>H</th>
#       <td>964</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>L</th>
#       <td>5648</td>
#       <td>231</td>
#     </tr>
#     <tr>
#       <th>M</th>
#       <td>2840</td>
#       <td>81</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# counting machine failures. already calculated using group by command.
sns.countplot(pd_df['Machine failure'])
pd.crosstab(pd_df['Machine failure'], columns='count')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[97]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>col_0</th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>Machine failure</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>9661</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>339</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# lets see failure and temperature relation.
sns.boxplot(x='Machine failure',y='Air temperature [K]',hue='Type', data=pd_df) # No major impact
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[98]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;matplotlib.axes._subplots.AxesSubplot at 0x7fb7644d99d0&gt;</div>

# %%
sns.boxplot(x='Machine failure',y='Process temperature [K]',hue='Type', data=pd_df)  # No major impact
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[99]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;matplotlib.axes._subplots.AxesSubplot at 0x7fb7643e5370&gt;</div>

# %%
# Relation between failure and speed of rotation 
sns.boxplot(x='Machine failure',y='Rotational speed [rpm]',hue='Type', data=pd_df) 
# we can see that there more outliers here and speed of rotation is less in failure comapred to non failire.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[100]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;matplotlib.axes._subplots.AxesSubplot at 0x7fb7642b4310&gt;</div>

# %%
# Relation between machine failiure and torque
sns.boxplot(x='Machine failure',y='Torque [Nm]',hue='Type', data=pd_df)# little impact 
# Torque is same for non-failure and there variation in torque at the time of failure
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[101]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;matplotlib.axes._subplots.AxesSubplot at 0x7fb75f5b2c70&gt;</div>

# %%
#There are little chances machien may fail beacuse of tool  wear.
sns.boxplot(x='Machine failure',y='Tool wear [min]',hue='Type', data=pd_df) # ''
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[102]: </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;matplotlib.axes._subplots.AxesSubplot at 0x7fb75f480e80&gt;</div>

# %%
df = df.drop('Type')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#copy of dataframe 

fail_df = df 
(train_data, test_data) = fail_df.randomSplit([0.7, 0.3], 24) #24 is random_state
print("Records for Training: " +str(train_data.count()))
print("Records for Training: " +str(test_data.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Records for Training: 6982
# Records for Training: 3018
# </div>

# %%
from pyspark.ml import Pipeline
from pyspark.ml.feature import OneHotEncoder, StringIndexer, VectorAssembler

#catColumns =["Type"]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
stages = []
#for catCol in catColumns:
  #stringIndexer = StringIndexer(inputCol=catCol, outputCol=catCol +"Index")
  #encoder = OneHotEncoder(inputCols=[stringIndexer.getOutputCol()], outputCols=[catCol +"catVec"])
  #stages +=[stringIndexer, encoder] 
# string values are converted to One not encoding
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
stages
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[107]: []</div>

# %%
# making list of numeric columns
numColumns = ['Air temperature [K]', 'Process temperature [K]','Rotational speed [rpm]','Torque [Nm]','Tool wear [min]']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# impute missing values.
from pyspark.ml.feature import Imputer
for numCol in numColumns:
  imputer = Imputer(inputCol=numCol, outputCol=numCol +"Index")
  stages+=[imputer]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# see the stages 
stages
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[110]: [Imputer_cb0c5cf0953f,
#  Imputer_c3a39eac4f45,
#  Imputer_ae6c51c298ce,
#  Imputer_8f1f6246ea2d,
#  Imputer_ec54ceb2a505]</div>

# %%
# lets check the missing values in new DataFrame
fail_df.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for (c) in df.columns]).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+-----------------------+----------------------+-----------+---------------+---------------+
# Air temperature [K]|Process temperature [K]|Rotational speed [rpm]|Torque [Nm]|Tool wear [min]|Machine failure|
# +-------------------+-----------------------+----------------------+-----------+---------------+---------------+
#                 264|                    287|                  1033|       1154|           1132|              0|
# +-------------------+-----------------------+----------------------+-----------+---------------+---------------+
#
# </div>

# %%
# put target column in stages
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
label_Idx = StringIndexer(inputCol="Machine failure", outputCol="label")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
stages += [label_Idx]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
stages
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[115]: [Imputer_cb0c5cf0953f,
#  Imputer_c3a39eac4f45,
#  Imputer_ae6c51c298ce,
#  Imputer_8f1f6246ea2d,
#  Imputer_ec54ceb2a505,
#  StringIndexer_ae96da0a25b2]</div>

# %%
# just to see how data gets fit and transform  
temp = label_Idx.fit(train_data).transform(train_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# see machine failure 0 is labeled as 0.0
temp.show(1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+-----------------------+----------------------+-----------+---------------+---------------+-----+
# Air temperature [K]|Process temperature [K]|Rotational speed [rpm]|Torque [Nm]|Tool wear [min]|Machine failure|label|
# +-------------------+-----------------------+----------------------+-----------+---------------+---------------+-----+
#                null|                   null|                  1445|       42.9|             55|              0|  0.0|
# +-------------------+-----------------------+----------------------+-----------+---------------+---------------+-----+
# only showing top 1 row
#
# </div>

# %%
# creating vector assembler, combine categorical columns and numeric columns
#assembleInputs = assemblerInputs = [c + "catVec" for c in catColumns] + [e + "Index" for e in numColumns]
#assembler = VectorAssembler(inputCols = assembleInputs, outputCol="features")
#stages += [assembler]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# creating vector assembler, combine categorical columns and numeric columns
assembleInputs = assemblerInputs =  [e + "Index" for e in numColumns]
assembler = VectorAssembler(inputCols = assembleInputs, outputCol="features")
stages += [assembler]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
stages
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[120]: [Imputer_cb0c5cf0953f,
#  Imputer_c3a39eac4f45,
#  Imputer_ae6c51c298ce,
#  Imputer_8f1f6246ea2d,
#  Imputer_ec54ceb2a505,
#  StringIndexer_ae96da0a25b2,
#  VectorAssembler_58c3fbbc7bb6]</div>

# %%
# Now create pipeline
pipeline = Pipeline().setStages(stages)
pipelineModel = pipeline.fit(train_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#need to transform the training and testing data. train preperation data and test preperation data
trainprepDF = pipelineModel.transform(train_data)
testprepDF = pipelineModel.transform(test_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# to see how does dataset look like
testprepDF.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[123]: Row(Air temperature [K]=None, Process temperature [K]=307.2, Rotational speed [rpm]=1372, Torque [Nm]=52.8, Tool wear [min]=33, Machine failure=&#39;0&#39;, Air temperature [K]Index=300.0250147318775, Process temperature [K]Index=307.2, Rotational speed [rpm]Index=1372, Torque [Nm]Index=52.8, Tool wear [min]Index=33, label=0.0, features=DenseVector([300.025, 307.2, 1372.0, 52.8, 33.0]))</div>

# %%
trainprepDF.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[124]: Row(Air temperature [K]=None, Process temperature [K]=None, Rotational speed [rpm]=1445, Torque [Nm]=42.9, Tool wear [min]=55, Machine failure=&#39;0&#39;, Air temperature [K]Index=300.0250147318775, Process temperature [K]Index=309.9899335793359, Rotational speed [rpm]Index=1445, Torque [Nm]Index=42.9, Tool wear [min]Index=55, label=0.0, features=DenseVector([300.025, 309.9899, 1445.0, 42.9, 55.0]))</div>

# %%
trainprepDF.select("Rotational speed [rpm]Index").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------------------------+
# Rotational speed [rpm]Index|
# +---------------------------+
#                        1445|
#                        1471|
#                        1496|
#                        1526|
#                        1715|
#                        1855|
#                        1351|
#                        1392|
#                        1429|
#                        1444|
#                        1456|
#                        1518|
#                        1668|
#                        1668|
#                        1412|
#                        1420|
#                        1514|
#                        1516|
#                        1555|
#                        1859|
# +---------------------------+
# only showing top 20 rows
#
# </div>

# %%
#create initial LogisticRegression model
from pyspark.ml.classification import LogisticRegression

lr = LogisticRegression(labelCol = "label", featuresCol = "features", maxIter=10)

#Train model with training data.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lrModel = lr.fit(trainprepDF)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print("Coefficients: " +str(lrModel.coefficients))
print("Intercept: " +str(lrModel.intercept))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Coeffic

# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">areaUnderROC = 0.5
# Out[135]: &#39;areaUnderROC&#39;</div>

# %%
from pyspark.mllib.evaluation import BinaryClassificationMetrics
results = predictions.select(['prediction', 'label'])

##prepare score-label set
results_collect = results.collect()
results_list = [(float(i[0]), float(i[1])) for i in results_collect]
predictionAndLabels = sc.parallelize(results_list)

metrics = BinaryClassificationMetrics(predictionAndLabels)

#Area under Precision-recall curve

print("Area under PR = %s" % metrics.areaUnderPR)

#Area Under ROC curve
print("Area under ROC = %s" % metrics.areaUnderROC)

predictions.show(1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Area under PR = 0.039761431411530816
# Area under ROC = 0.5
# +-------------------+-----------------------+----------------------+-----------+---------------+---------------+------------------------+----------------------------+---------------------------+----------------+--------------------+-----+--------------------+--------------------+--------------------+----------+
# Air temperature [K]|Process temperature [K]|Rotational speed [rpm]|Torque [Nm]|Tool wear [min]|Machine failure|Air temperature [K]Index|Process temperature [K]Index|Rotational speed [rpm]Index|Torque [Nm]Index|Tool wear [min]Index|label|            features|       rawPrediction|         probability|prediction|
# +-------------------+-----------------------+----------------------+-----------+---------------+---------------+------------------------+----------------------------+---------------------------+----------------+--------------------+-----+--------------------+--------------------+--------------------+----------+
#                null|                  307.2|                  1372|       52.8|             33|              0|       300.0250147318775|                       307.2|                       1372|            52.8|                  33|  0.0|[300.025014731877...|[3.11034942017399...|[0.95731763557443...|       0.0|
# +-------------------+-----------------------+----------------------+-----------+---------------+---------------+------------------------+----------------------------+---------------------------+----------------+--------------------+-----+--------------------+--------------------+--------------------+----------+
# only showing top 1 row
#
# </div>

# %%
count = predictions.count()
correct = results.filter(results.prediction == results.label).count()
wrong = results.filter(results.prediction != results.label).count()
tp = results.filter(results.prediction == 1.0).filter(results.prediction == results.label).count()
fp = results.filter(results.prediction == 1.0).filter(results.prediction != results.label).count()
fn = results.filter(results.prediction == 0.0).filter(results.prediction != results.label).count()
tn = results.filter(results.prediction == 0.0).filter(results.prediction == results.label).count()

accuracy = (tp+tn)/count

#precision = tp/(tp+fp)

recall = tp/(tp+fn)

print("correct: %s\nWrong: %s\ntp: %s\nfp: %s\nfn: %s\ntn: %s\nAccuracy: %s\nPrecision: %s\nRecall: %s" %(correct, wrong, tp, fp, fn, tn, accuracy, precision, recall))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">correct: 2898
# Wrong: 120
# tp: 0
# fp: 0
# fn: 120
# tn: 2898
# Accuracy: 0.9602385685884692
# Precision: 0.9382511078739856
# Recall: 0.0
# </div>

# %%
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator

# Create ParamGrid for Cross Validation
paramGrid = (ParamGridBuilder()
            .addGrid(lr.regParam, [0.01, 0.5,1.0])
             .addGrid(lr.elasticNetParam, [0.0,0.5,1.0])
             .addGrid(lr.maxIter, [5,10,20])
             .build())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cv = CrossValidator(estimator=lr, estimatorParamMaps=paramGrid, evaluator=evaluatorLR, numFolds=5)

#Run cross validiations
cvModel = cv.fit(trainprepDF)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/ml/util.py:800: UserWarning: Cannot find mlflow module. To enable MLflow logging, install mlflow from PyPI.
#   warnings.warn(_MLflowInstrumentation._NO_MLFLOW_WARNING)
# </div>

# %%
predictions = cvModel.bestModel.transform(testprepDF)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
evaluatorLR.evaluate(predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[142]: 0.5</div>

# %%
results = predictions.select(['prediction', 'label'])

count=predictions.count()
correct = results.filter(results.prediction == results.label).count()
wrong = results.filter(results.prediction != results.label).count()
tp = results.filter(results.prediction == 1.0).filter(results.prediction == results.label).count()
fp = results.filter(results.prediction == 1.0).filter(results.prediction != results.label).count()
fn = results.filter(results.prediction == 0.0).filter(results.prediction != results.label).count()
tn = results.filter(results.prediction == 0.0).filter(results.prediction == results.label).count()
accuracy = (tp+tn)/count

#precision = tp/(tp+fp)

print("correct: %s\nWrong: %s\ntp: %s\nfp: %s\nfn: %s\ntn: %s\nAccuracy: %s\nPrecision: %s\nRecall: %s" %(correct, wrong, tp, fp, fn, tn, accuracy, precision, recall))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">correct: 2898
# Wrong: 120
# tp: 0
# fp: 0
# fn: 120
# tn: 2898
# Accuracy: 0.9602385685884692
# Precision: 0.9382511078739856
# Recall: 0.0
# </div>

# %%
cvModel.explainParams()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[145]: &#34;estimator: estimator to be cross-validated (current: LogisticRegression_105cb0726058)\nestimatorParamMaps: estimator param maps (current: [{Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;regParam&#39;, doc=&#39;regularization parameter (&gt;= 0).&#39;): 0.01, Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;elasticNetParam&#39;, doc=&#39;the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.&#39;): 0.0, Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;maxIter&#39;, doc=&#39;max number of iterations (&gt;= 0).&#39;): 5}, {Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;regParam&#39;, doc=&#39;regularization parameter (&gt;= 0).&#39;): 0.01, Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;elasticNetParam&#39;, doc=&#39;the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.&#39;): 0.0, Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;maxIter&#39;, doc=&#39;max number of iterations (&gt;= 0).&#39;): 10}, {Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;regParam&#39;, doc=&#39;regularization parameter (&gt;= 0).&#39;): 0.01, Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;elasticNetParam&#39;, doc=&#39;the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.&#39;): 0.0, Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;maxIter&#39;, doc=&#39;max number of iterations (&gt;= 0).&#39;): 20}, {Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;regParam&#39;, doc=&#39;regularization parameter (&gt;= 0).&#39;): 0.01, Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;elasticNetParam&#39;, doc=&#39;the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.&#39;): 0.5, Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;maxIter&#39;, doc=&#39;max number of iterations (&gt;= 0).&#39;): 5}, {Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;regParam&#39;, doc=&#39;regularization parameter (&gt;= 0).&#39;): 0.01, Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;elasticNetParam&#39;, doc=&#39;the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.&#39;): 0.5, Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;maxIter&#39;, doc=&#39;max number of iterations (&gt;= 0).&#39;): 10}, {Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;regParam&#39;, doc=&#39;regularization parameter (&gt;= 0).&#39;): 0.01, Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;elasticNetParam&#39;, doc=&#39;the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.&#39;): 0.5, Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;maxIter&#39;, doc=&#39;max number of iterations (&gt;= 0).&#39;): 20}, {Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;regParam&#39;, doc=&#39;regularization parameter (&gt;= 0).&#39;): 0.01, Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;elasticNetParam&#39;, doc=&#39;the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.&#39;): 1.0, Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;maxIter&#39;, doc=&#39;max number of iterations (&gt;= 0).&#39;): 5}, {Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;regParam&#39;, doc=&#39;regularization parameter (&gt;= 0).&#39;): 0.01, Param(parent=&#39;LogisticRegression_105cb0726058&#39;, name=&#39;ela ...

# %%
from pyspark.ml.classification import RandomForestClassifier

rf = RandomForestClassifier(labelCol="label", featuresCol="features").setImpurity("gini").setMaxDepth(6).setNumTrees(50).setFeatureSubsetStrategy("auto").setSeed(1010)

rfModel = rf.fit(trainprepDF)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions = rfModel.transform(testprepDF)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
results = predictions.select(['prediction', 'label'])

count=predictions.count()
correct = results.filter(results.prediction == results.label).count()
wrong = results.filter(results.prediction != results.label).count()
tp = results.filter(results.prediction == 1.0).filter(results.prediction == results.label).count()
fp = results.filter(results.prediction == 1.0).filter(results.prediction != results.label).count()
fn = results.filter(results.prediction == 0.0).filter(results.prediction != results.label).count()
tn = results.filter(results.prediction == 0.0).filter(results.prediction == results.label).count()

accuracy = (tp+tn)/count

precision = tp/(tp+fp)

recall = tp/(tp+fn)

print("correct: %s\nWrong: %s\ntp: %s\nfp: %s\nfn: %s\ntn: %s\nAccuracy: %s\nPrecision: %s\nRecall: %s" %(correct, wrong, tp, fp, fn, tn, accuracy, precision, recall))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">correct: 2934
# Wrong: 84
# tp: 43
# fp: 7
# fn: 77
# tn: 2891
# Accuracy: 0.9721669980119284
# Precision: 0.86
# Recall: 0.35833333333333334
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
